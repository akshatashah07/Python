# %%
a = 10
b = 5
print (a-b)
print(a+b)
# Out:
# 5
# 15

# %% [markdown]
# ## Topic Name
# hiee we are using jupyter notebook today for python
# this is **demo**

# %%
ca$h = 100
# Out:
#   Cell In[1], line 1
#     ca$h = 100
#       ^
# SyntaxError: invalid syntax

# %%
abc1 = 23

# %%
1abc = 23
# Out:
#   Cell In[3], line 1
#     1abc = 23
#     ^
# SyntaxError: invalid decimal literal

# %%
Total = 100
total = 200

# %%
import keyword
print (keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
print(len(keyword.kwlist))
# Out:
# 35

# %%
"abc".isidentifier()
# Out:
# True

# %%
a = "LJeng"

# %%
a = 'LJENG'

# %% [markdown]
# -- numeric type - int, float

# %%
x = 1
y = 505027
z = 4905

# %% [markdown]
# -- check its type

# %%
print(type(y))
# Out:
# <class 'int'>

# %%
a = 0b1111
print(a)
# Out:
# 15

# %%
b = 0o123
print(b)
# Out:
# 83

# %%
c = 0x123A
print(c)
# Out:
# 4666

# %% [markdown]
# Base Conversion

# %% [markdown]
# --binary

# %%
a = bin(15)
print(a)
b = bin(0o11)
print(b)
c = bin(0x100)
print(c)
# Out:
# 0b1111
# 0b1001
# 0b100000000

# %% [markdown]
# --octal

# %%
a = oct(10)
print(a)
b = oct(0b1111)
print(b)
c = oct(0x123)
print(c)
# Out:
# 0o12
# 0o17
# 0o443

# %% [markdown]
# --hex

# %%
hex(100)
# Out:
# '0x64'

# %%
hex(0b11111)
# Out:
# '0x1f'

# %%
hex(0o12345)
# Out:
# '0x14e5'

# %% [markdown]
# -- float

# %%
a = 36e3
print(a)
# Out:
# 36000.0

# %% [markdown]
# * Sequence type - list, tuple, range

# %% [markdown]
# 1.) list

# %%
l1 = [1,2,3,4,5,5]

# %%
l2 = ['apple', 'cherry', 'banana']
l3 = [1, 2, 'apple','banana']
l4 = [True, False, True]

# %%
print(l1)
# Out:
# [1, 2, 3, 4, 5, 5]

# %%
print(l2)
print(l3)
print(l4)
# Out:
# ['apple', 'cherry', 'banana']
# [1, 2, 'apple', 'banana']
# [True, False, True]

# %% [markdown]
# 2.) Range

# %%
a = range(10)
print(a)
# Out:
# range(0, 10)

# %%
a = range(0,10,2)
print(a)
# Out:
# range(0, 10, 2)

# %%
a = range(0,10,2)
print(list(a))
# Out:
# [0, 2, 4, 6, 8]

# %% [markdown]
# 3.) Tuple

# %%
t1 = (1,2,3,4,5)
print(t1)
# Out:
# (1, 2, 3, 4, 5)

# %% [markdown]
# -- to change list

# %%
l1[3] = 10
print(l1)
# Out:
# [1, 2, 3, 10, 5, 5]
